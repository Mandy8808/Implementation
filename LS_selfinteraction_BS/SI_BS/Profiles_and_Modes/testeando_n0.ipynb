 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.6744444444444445],
 [1.6890431931001775, 21.353957555304195, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.68],
 #[1.894, 21.353957555304195, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.68540221],
 #[2.1, 21.353957555304195, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.680197554],
[2.5, 18.04594055695054, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.643187880980042],
[3.0, 16.37758645781133, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.5536298915662671],
[3.5, 15.352578501938119, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.4224984415040014],
[4.0, 13.928843274956668, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.2544152281407275],
[4.2, 13.826688488420878, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.1775543033918221],
[4.5, 13.074645748692468, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.05241919385153261]
]]

# %%
Umax = 15
Umin = 13
f0 = 15.0
nodos = 0
alf = 1
rmin = 0
rmax = 100 #1e03
met = 'DOP853' # 'RK45' # 'DOP853'
Rtol = 1e-13 
Atol = 1e-15

# en, Mas, rD, sD, dsD, uD, duD, cer0, LamV  = ru.profiles2(nodos, Lam, f0, umin=Umin, umax=Umax, met='DOP853')

datos = []
for i in [0]:
    Lamb = i 
    U0, rTemp, posNodos = ru.Freq_solveG2(f0, Umax, Umin, Lamb, alf, rmax, rmin, nodos,met=met,
                                  Rtol=Rtol, Atol=Atol)

    datos.append([f0, rTemp, alf, i, nodos, posNodos, met, Rtol, Atol, U0])

# %%
datBG = datos[0]
#datBG[-1] = 170

# Resolviendo
en, Mas, rD, sD, dsD, uD, duD, cer0, LamV = ru.profilesFromSolut(datBG)
plt.plot(rD, sD)
#plt.xlim(0, 10)
#plt.ylim(-0.1, 15.1)

# %%
datos

# %%
solPlotP1 = [[2.0, 12.940420123083182, 1, 1, 0, None, 'RK45', 1e-06, 1e-08, 4.5252768225014846],
             [3.0, 9.94578658438782, 1, 1, 0, None, 'RK45', 1e-06, 1e-08, 9.512734698899479],
             [4.0, 8.551967119225445, 1, 1, 0, None, 'RK45', 1e-06, 1e-08, 16.50628378190295],
             [6.0, 5.978170758291572, 1, 1, 0, None, 'DOP853', 1e-13, 1e-15, 36.50247902928267],
             [8.0, 4.7059858387600375, 1, 1, 0, None, 'DOP853', 1e-13, 1e-15, 64.50134992119744],
             [10.0, 4.291104560098033, 1, 1, 0, None, 'RK45', 1e-06, 1e-08, 100.50085223978913]
             ]

solPlotM1 = [[1.0, 26.35148536319269, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.5667978718259771],
[2.5, 18.04594055695054, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.643187880980042],
[3.0, 16.37758645781133, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.5536298915662671],
[3.5, 15.352578501938119, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.4224984415040014],
[4.0, 13.928843274956668, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.2544152281407275],
[4.2, 13.826688488420878, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.1775543033918221],
[4.5, 13.074645748692468, 1, -1, 0, None, 'DOP853', 1e-13, 1e-15, 0.05241919385153261]]

solPlotP0 = [[1.0, 24.19121506258424, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 0.9185797718046369],
[4.0, 12.429944565573805, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 3.674319087218551],
[5.0, 10.869582207654839, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 4.5928988590231885],
[6.0, 9.483460137104279, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 5.511478630827813],
[7.0, 8.999869270951702, 1, 0, 0, None, 'DOP853',  1e-13, 1e-15, 6.4300584026324685],
[8.0, 8.26107003851312, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 7.348638174437085],
[9.0, 7.8601410298023575, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 8.267217946241729],
[10.0, 7.653465705786873, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 9.185797718046373],
[11.0, 7.333959400227217, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 10.104377489851018],
[12.0, 6.838591858783329, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 11.022957261655662],
[13.0, 6.692568783402776, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 11.941537033460307],
[14.0, 6.658479292196162, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 12.860116805264923],
[15.0, 6.395890645858537, 1, 0, 0, None, 'DOP853', 1e-13, 1e-15, 13.778696577069567]

]

# %%
soluciones_Fondo = [
[2.0, 12.940420123083182, 1, 1, 0, None, 'RK45', 1e-06, 1e-08, 4.5252768225014846],
             [3.0, 9.94578658438782, 1, 1, 0, None, 'RK45', 1e-06, 1e-08, 9.512734698899479],
             [4.0, 8.551967119225445, 1, 1, 0, None, 'RK45', 1e-06, 1e-08, 16.50628378190295],
             [6.0, 5.978170758291572, 1, 1, 0, None, 'DOP853', 1e-13, 1e-15, 36.50247902928267],
             [8.0, 4.7059858387600375, 1, 1, 0, None, 'DOP853', 1e-13, 1e-15, 64.50134992119744],
             [10.0, 4.291104560098033, 1, 1, 0, None, 'RK45', 1e-06, 1e-08, 100.50085223978913]
    ]

# %%
soluciones_Fondo=DataFondo[2][10:]

# %%
##########################
# EXTENDIENDO SOLUCIONES #
##########################
Ncasos = range(len(soluciones_Fondo))

datosProfiles = []
Edata = []
for i in Ncasos:
    datBG = soluciones_Fondo[i]
    s0 = datBG[0]
    r0M = datBG[1]
    Ext = (s0*r0M)+7000
    Np = int(Ext/2)
    rtake = -160
    # Resolviendo
    en, Mas, rD, sD, dsD, uD, duD, cer0, LamV = ru.profilesFromSolut(datBG) 
    # Extendiendo
    rDnew, sDnew, dsDnew, uDnew, duDnew, datosEquiv = ru.extend(rD[:rtake], sD[:rtake], dsD[:rtake], uD[:rtake], duD[:rtake],
                                                                Ext, Np, inf=False)
    print(Ext, Np, r0M, rDnew[-1])

    # interpolación de los datos
    fsN = interp1d(rDnew, sDnew, kind='quadratic') # quadratic
    fdsN = interp1d(rDnew, dsDnew, kind='linear')
    fuN = interp1d(rDnew, uDnew, kind='quadratic')
    fduN = interp1d(rDnew, duDnew, kind='quadratic')

    # Equivalencia
    masatest, Entest, sD0test = datosEquiv  # M -> K
    Edata.append([rDnew[-1], Entest, (Entest-uDnew)[-1], fsN(rDnew[-1])])

    #plt.plot(rDnew, np.abs(Entest-uDnew), label=r'%d'%i)  # u = E - Uf
    plt.plot(rDnew, sDnew, label=r'%3.2f'%s0)  # u = E - Uf
    # salvando
    datosProfiles.append([fsN, fdsN, fuN, fduN])
    
plt.legend()
#plt.xscale('log')
#plt.yscale('log')

# %%
#########################################
# Calculando los autovalores (Espectro) #
#########################################

def NpuntosCho(s0):
  if s0>=3.5:
    Nptos = int(rMax/2)
  elif s0>=2.5:
    Nptos = int(rMax/4)
  elif s0>=1.5:
    Nptos = int(rMax/5)
  elif s0>=0.5:
    Nptos = int(rMax/6)
  elif s0>=0.05:
    Nptos = int(rMax/7)
  else:
    Nptos = int(rMax/8)
  return Nptos

dist = [0.7, 0.8, 0.9, 1]
ptosVal = [100, 250, 500, 750, 1000]

# Ncasos = range(len(datosProfiles))  # numero de soluciones que se estudiarán

# cada fila es un valor de Nptos y columna una solución sigma0
Lval = 2

Auto_Real, Auto_Valores, Auto_Funciones = [], [], []
dataPtos = []
for k in Ncasos: #Ncasos:
    fsNtmp, fuNtmp = datosProfiles[k][0], datosProfiles[k][2]

    rfin, alpha, Lamb, nodos = soluciones_Fondo[k][1], soluciones_Fondo[k][2], soluciones_Fondo[k][3], soluciones_Fondo[k][4]
    
    s0 = fsNtmp(0)
    rMax = rfin+200*(nodos+1) #dist[2]*rDnew[-1]  #rfin+200*(nodos+1)
    Nptos = NpuntosCho(s0)+1000 #NpuntosCho(s0)+ptosVal[3] # NpuntosCho(s0)+1000
    dataPtos.append([s0, rMax, Nptos])
    print(Nptos, fsNtmp(rMax), Edata[k][1]-fuNtmp(rMax))
    
    L = Lval
    util = [Nptos, rMax, Lamb, alpha, L]    
    datFunc = [fsNtmp, fuNtmp]

    lambd, _, Vecto_Full, _ = ru.espectroL(datFunc, util, inf=False)

    #### Separando los Autovalores ######
    jj = np.real(lambd)!=0  # reales
    autoval_Real = lambd[jj]
    print('')
    print('Autovalores con part. Real para rho_0=%7.6f, Npt.=%d -> '%(fsNtmp(0), Nptos), autoval_Real)
    
    if len(autoval_Real)!=0:
        #temp = len(autoval_Real)
        #name = 'data_real%d.dat'%(k)
        #data = np.array([[k]*temp, autoval_Real.real, autoval_Real.imag]).T
        #np.savetxt(name, data)
        Auto_Real.append(k)
    ###############

    ###### Organizando de menor a mayor los autovalores #####
    indF = ru.menor(lambd).astype(int)
    autova_Organ = lambd[indF]

    ###### Salvando  #####
    Auto_Valores.append(autova_Organ)
    Auto_Funciones.append(Vecto_Full[:, indF])

# %%
Autovalores2P = []
for i in Auto_Valores:
    jj = np.real(i)!=0  # reales
    kk = np.real(i)>8e-03
    jj=kk*jj
    autoval_Real = i[jj]
    Autovalores2P.append(autoval_Real)

# %%
s0data = [i[0] for i in soluciones_Fondo]

# %%
np.save('AutovN0ML0_2.npy', np.array([s0data, Autovalores2P], dtype=object))

# %%
Ncasos = range(len(soluciones_Fondo))

datosProfiles = []
Edata = []
for i in Ncasos:
    datBG = soluciones_Fondo[i]

# %%
Ncasos = range(len(soluciones_Fondo))

k = 0
rmin = 0
radSigmMasa, Sig0R99M99EnergyT = [], []
for j in Ncasos:
    # Resolviendo Numericamente
    f0, rTemp, alf, Lam, nodos, posNodos, met, Rtol, Atol, u0 = soluciones_Fondo[j]
    print(f0)
    arg = [Lam, alf]
    rspan = np.linspace(rmin, rTemp, 1000)
    V0 = [f0, 0., u0, 0.]
    sol = solve_ivp(ru.system, [rmin, rTemp], V0, t_eval=rspan,
                        args=(arg,), method=met, rtol=Rtol, atol=Atol)
    
    # Interpolando perfil numerico
    r, sigma = sol.t, sol.y[0]
    sigmaPerf = interp1d(r, sigma)

    # Masa perfil
    Intdensidad = lambda r: (r**2)*sigmaPerf(r)**2
    MasaData = []
    for ii in r:
        temp = quad(Intdensidad, r[0], ii)[0]
        MasaData.append(temp)
        
    # sigma0, R99, M99, E
    # R99
    MTotal = MasaData[-1]
    #print('Masa 99 ', 0.99*MTotal)
    valM, indx = ru.find_nearest(MasaData, 0.99*MTotal)
    R99, M99 = r[indx], MasaData[indx]
    #print('Radio 99 ', R99, 'Masa 99 ', M99)

    # E- valor
    energyPro = lambda r: r*sigmaPerf(r)**2
    Energy = u0 - quad(energyPro, r[0], r[-1])[0]   # energia barra

    # Salvando
    radSigmMasa.append([r, sigma, MasaData])  # salvando r, sigma(r), M(r)
    Sig0R99M99EnergyT.append([f0, R99, M99, Energy])  # salvando sigma0, R99, M99, E

# Salvando
np.savez('radSigmMasa_n0_Pos', np.array(radSigmMasa, dtype=object))
np.savez('Sig0R99M99EnergyT_n0_Pos', np.array(Sig0R99M99EnergyT))

# %%
Sig0R99M99EnergyT
