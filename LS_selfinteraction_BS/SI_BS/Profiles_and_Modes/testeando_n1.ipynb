# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import rutinas_AutoInt as ru

from scipy.interpolate import interp1d
from scipy.integrate import solve_ivp, quad

# %%
DataFondo = [
[  # Lambda=0
 [4.9545831664676865e-05, 3581.4857398015843, 1, 0, 1, 475.71901466, 'DOP853', 1e-13, 1e-15, 5.994842503189409e-05],
 [0.0001378642197347623, 2207.829783577727, 1, 0, 1, 285.18605686, 'DOP853', 1e-13, 1e-15, 0.0001668100537200059],
 [0.00038361538085363034, 1408.621439497485, 1, 0, 1, 170.9645495, 'DOP853', 1e-13, 1e-15, 0.00046415888336127773],
 [0.0010674325848243351, 842.1128839573636, 1, 0, 1, 102.49055479, 'DOP853', 1e-13, 1e-15, 0.0012915496650148827],
 [0.00297019457512695, 541.3676791144267, 1, 0, 1, 61.4414734, 'DOP853', 1e-13, 1e-15, 0.003593813663804626],
 [0.008264742841403196, 318.11525102465816, 1, 0, 1, 36.83319562, 'DOP853', 1e-13, 1e-15, 0.01],
 [0.02479422852420958, 185.17274642629613, 1, 0, 1, 21.26565541, 'DOP853', 1e-13, 1e-15, 0.03],
 [0.028926599944912916, 173.98714032588052, 1, 0, 1, 19.68817121, 'DOP853', 1e-13, 1e-15, 0.035],
 [0.033058971365613934, 168.3256856346453, 1, 0, 1, 18.41659781, 'DOP853', 1e-13, 1e-15, 0.04],
 [0.03719134278631493, 152.86601699542624, 1, 0, 1, 17.36333493, 'DOP853', 1e-13, 1e-15, 0.045],
 [0.04132371420701826, 145.79976448011405, 1, 0, 1, 16.47230585, 'DOP853', 1e-13, 1e-15, 0.05],
 [0.045456085627719287, 152.29696419605847, 1, 0, 1, 15.70572738, 'DOP853', 1e-13, 1e-15, 0.055],
 [0.04958845704842031, 133.84324990362305, 1, 0, 1, 15.03708914, 'DOP853', 1e-13, 1e-15, 0.06],
 [0.05372082846912364, 128.05082397593313, 1, 0, 1, 14.44716794, 'DOP853', 1e-13, 1e-15, 0.065],
 [0.05785319988982468, 127.19516339428077, 1, 0, 1, 13.92163937, 'DOP853', 1e-13, 1e-15, 0.07],
 [0.06198557131052569, 121.05635563840418, 1, 0, 1, 13.4495814, 'DOP853', 1e-13, 1e-15, 0.075],
 [0.06611794273122902, 115.44190247254183, 1, 0, 1, 13.0225012, 'DOP853', 1e-13, 1e-15, 0.08],
 [0.07025031415193005, 114.25064118916512, 1, 0, 1, 12.63368187, 'DOP853', 1e-13, 1e-15, 0.085],
 [0.07438268557263103, 111.6709117802037, 1, 0, 1, 12.27773187, 'DOP853', 1e-13, 1e-15, 0.09],
 [0.07851505699333207, 106.59317281027394, 1, 0, 1, 11.95026668, 'DOP853', 1e-13, 1e-15, 0.095],
 [0.08264742841403537, 105.26488192061736, 1, 0, 1, 11.64767917, 'DOP853', 1e-13, 1e-15, 0.1],
 [0.09917691409684179, 98.92675838617005, 1, 0, 1, 10.6328277, 'DOP853', 1e-13, 1e-15, 0.12],
 [0.1157063997796482, 90.36738841149118, 1, 0, 1, 9.84408561, 'DOP853', 1e-13, 1e-15, 0.14],
 [0.13223588546245457, 83.03686577303469, 1, 0, 1, 9.20829891, 'DOP853', 1e-13, 1e-15, 0.16],
 [0.14876537114526323, 78.86221908524094, 1, 0, 1, 8.68166747, 'DOP853', 1e-13, 1e-15, 0.18],
 [0.1652948568280696, 78.33435018878428, 1, 0, 1, 8.23615292, 'DOP853', 1e-13, 1e-15, 0.2],
 [0.18182434251087598, 72.77379581108214, 1, 0, 1, 7.85286369, 'DOP853', 1e-13, 1e-15, 0.22],
 [0.1983538281936824, 68.68322465010733, 1, 0, 1, 7.51854457, 'DOP853', 1e-13, 1e-15, 0.24],
 [0.21488331387649107, 65.70571934536258, 1, 0, 1, 7.22358397, 'DOP853', 1e-13, 1e-15, 0.26],
 [0.23141279955929756, 64.41389324004842, 1, 0, 1, 6.96081969, 'DOP853', 1e-13, 1e-15, 0.28],
 [0.24794228524210393, 65.00175520088347, 1, 0, 1, 6.7247907, 'DOP853', 1e-13, 1e-15, 0.3],
 [0.2644717709249103, 59.658885238024894, 1, 0, 1, 6.5112506, 'DOP853', 1e-13, 1e-15, 0.32],
 [0.28283786612802986, 58.88791147018336, 1, 0, 1, 6.29629831, 'DOP853', 1e-13, 1e-15, 0.34222222222222226],
 [0.5574109894146542, 41.44900771105778, 1, 0, 1, 4.48503988, 'DOP853', 1e-13, 1e-15, 0.6744444444444445],
 [0.831984112701283, 34.37600775952209, 1, 0, 1, 3.67110288, 'DOP853', 1e-13, 1e-15, 1.0066666666666668],
 [1.106557235987908, 30.091186881375197, 1, 0, 1, 3.18322349, 'DOP853', 1e-13, 1e-15, 1.338888888888889],
 [1.3811303592745343, 27.696900078365353, 1, 0, 1, 2.84929054, 'DOP853', 1e-13, 1e-15, 1.6711111111111112],
 [1.655703482561158, 24.321271164661066, 1, 0, 1, 2.60233253, 'DOP853', 1e-13, 1e-15, 2.0033333333333334],
 [1.930276605847787, 22.88975381741925, 1, 0, 1, 2.41015125, 'DOP853', 1e-13, 1e-15, 2.3355555555555556],
 [2.2048497291344122, 21.660399860887757, 1, 0, 1, 2.25509361, 'DOP853', 1e-13, 1e-15, 2.667777777777778],
 [2.4794228524210373, 20.516079459757748, 1, 0, 1, 2.12656554, 'DOP853', 1e-13, 1e-15, 3.0],
 [2.892659994491212, 18.9719631719841, 1, 0, 1, 1.96881712, 'DOP853', 1e-13, 1e-15, 3.5],
[3.7191342786315564, 17.082225587976883, 1, 0, 1, 1.73633349, 'DOP853', 1e-13, 1e-15, 4.5],
[4.132371420701732, 15.560987446892115, 1, 0, 1, 1.64723058, 'DOP853', 1e-13, 1e-15, 5],
[4.545608562771905, 14.746651337046577, 1, 0, 1, 1.57057274, 'DOP853', 1e-13, 1e-15, 5.5],
[4.958845704842069, 14.104875403597887, 1, 0, 1, 1.50370891, 'DOP853', 1e-13, 1e-15, 6],
[5.372082846912248, 13.740591085121368, 1, 0, 1, 1.44471679, 'DOP853', 1e-13, 1e-15, 6.5],
[5.7853199889824225, 13.341087065985924, 1, 0, 1, 1.39216394,'DOP853', 1e-13, 1e-15, 7],
[6.198557131052597, 13.241276099856535, 1, 0, 1, 1.34495814, 'DOP853', 1e-13, 1e-15, 7.5],
[6.61179427312277, 12.710868495143586, 1, 0, 1, 1.30225012, 'DOP853', 1e-13, 1e-15, 8],
[7.025031415192942, 11.939835484432983, 1, 0, 1, 1.26336819, 'DOP853', 1e-13, 1e-15, 8.5],
[7.438268557263115, 11.854381568065547, 1, 0, 1, 1.22777319, 'DOP853', 1e-13, 1e-15, 9.0],
[7.8515056993332895, 12.055037593156287, 1, 0, 1, 1.19502667, 'DOP853', 1e-13, 1e-15, 9.5],
[8.26474284140347, 10.847677516800784, 1, 0, 1, 1.16476792, 'DOP853', 1e-13, 1e-15, 10]
],
[ # Lambda=1
[4.954509408072738e-05, 3690.333586884089, 1, 1, 1, 475.7238859, 'DOP853', 1e-13, 1e-15, 5.994842503189409e-05],
[0.0001378585090865414, 2205.6427753811213, 1, 1, 1, 285.1941825, 'DOP853', 1e-13, 1e-15, 0.0001668100537200059],
[0.0003835711694240018, 1357.8903719958596, 1, 1, 1, 170.97810342, 'DOP853', 1e-13, 1e-15, 0.00046415888336127773],
[0.0010670903592124859, 862.5703251572552, 1, 1, 1, 102.51316197, 'DOP853', 1e-13, 1e-15, 0.0012915496650148827],
[0.0029675467283909462, 509.31708610690663, 1, 1, 1, 61.47917465, 'DOP853', 1e-13, 1e-15, 0.003593813663804626],
[0.008244281958451172, 316.700984171284, 1, 1, 1, 36.89603964, 'DOP853', 1e-13, 1e-15, 0.01],
[0.024611207231652, 186.22749571815766, 1, 1, 1, 21.37425995, 'DOP853', 1e-13, 1e-15, 0.03],
[0.028677868001590223, 173.65204351885836, 1, 1, 1, 19.80541184, 'DOP853', 1e-13, 1e-15, 0.035],
[0.03273459224798314, 164.82890502100042, 1, 1, 1, 18.54186323, 'DOP853', 1e-13, 1e-15, 0.04],
[0.036781425317474525, 152.2198879541536, 1, 1, 1, 17.49612479, 'DOP853', 1e-13, 1e-15, 0.045],
[0.04081841227386773, 144.47257924987213, 1, 1, 1, 16.61220061, 'DOP853', 1e-13, 1e-15, 0.05],
[0.04484559790034526, 150.29384773313453, 1, 1, 1, 15.85236856, 'DOP853', 1e-13, 1e-15, 0.055],
[0.04886302670166698, 133.0099743131769, 1, 1, 1, 15.19016571, 'DOP853', 1e-13, 1e-15, 0.06],
[0.05287074290633109, 128.4521839430233, 1, 1, 1, 14.60640664, 'DOP853', 1e-13, 1e-15, 0.065],
[0.056868790468748376, 124.03901769911197, 1, 1, 1, 14.08679757, 'DOP853', 1e-13, 1e-15, 0.07],
[0.0608572130713525, 120.78002787862386, 1, 1, 1, 13.62044175, 'DOP853', 1e-13, 1e-15, 0.075],
[0.06483605412673166, 115.63702439036123, 1, 1, 1, 13.19886747, 'DOP853', 1e-13, 1e-15, 0.08],
[0.06880535677972022, 114.93133254763444, 1, 1, 1, 12.81537572, 'DOP853', 1e-13, 1e-15, 0.085],
[0.07276516390946375, 111.354360754013, 1, 1, 1, 12.46459026, 'DOP853', 1e-13, 1e-15, 0.09],
[0.07671551813148136, 108.23578963528477, 1, 1, 1, 12.14213975, 'DOP853', 1e-13, 1e-15, 0.095],
[0.08065646179970676, 107.67586113862478, 1, 1, 1, 11.8444286, 'DOP853', 1e-13, 1e-15, 0.1],
[0.09632696897006054, 95.64287438519204, 1, 1, 1, 10.84788417, 'DOP853', 1e-13, 1e-15, 0.12],
[0.11185022893646446, 88.2245392850154, 1, 1, 1, 10.07586759, 'DOP853', 1e-13, 1e-15, 0.14],
[0.12722883104748073, 84.55420398917708, 1, 1, 1, 9.45554803, 'DOP853', 1e-13, 1e-15, 0.16],
[0.14246530262982526, 78.82084975661685, 1, 1, 1, 8.9433504, 'DOP853', 1e-13, 1e-15, 0.18],
[0.15756211084731797, 75.76767760573803, 1, 1, 1, 8.51140065, 'DOP853', 1e-13, 1e-15, 0.2],
[0.1725216644933023, 71.52637102348491, 1, 1, 1, 8.14093157, 'DOP853', 1e-13, 1e-15, 0.22],
[0.18734631571938243, 68.4193356673308, 1, 1, 1, 7.81878487, 'DOP853', 1e-13, 1e-15, 0.24],
[0.2020383617030146, 66.95574525389021, 1, 1, 1, 7.53542621, 'DOP853', 1e-13, 1e-15, 0.26],
[0.21660004625650808, 67.63970781238527, 1, 1, 1, 7.28375624, 'DOP853', 1e-13, 1e-15, 0.28],
[0.23103356137979647, 62.738858458673086, 1, 1, 1, 7.05836585, 'DOP853', 1e-13, 1e-15, 0.3],
[0.245341048759252, 61.56722666983148, 1, 1, 1, 6.85505214, 'DOP853', 1e-13, 1e-15, 0.32],
[0.2610929904805883, 57.9905673822568, 1, 1, 1, 6.65102377, 'DOP853', 1e-13, 1e-15, 0.34222222222222226],
[0.48007747990108873, 42.62427493055643, 1, 1, 1, 4.96700172, 'DOP853', 1e-13, 1e-15, 0.6744444444444445],
[0.673043353653854, 35.1145399534163, 1, 1, 1, 4.24246009, 'DOP853', 1e-13, 1e-15, 1.0066666666666668],
[0.8455302510684798, 31.574185261613096, 1, 1, 1, 3.8240253, 'DOP853', 1e-13, 1e-15, 1.338888888888889],
[1.0015670860263874, 27.45755342103556, 1, 1, 1, 3.54683271, 'DOP853', 1e-13, 1e-15, 1.6711111111111112],
[1.1441584780658358, 25.43500002714395, 1, 1, 1, 3.34772186, 'DOP853', 1e-13, 1e-15, 2.0033333333333334],
[1.2755938838963536, 23.785243877959243, 1, 1, 1, 3.19678831, 'DOP853', 1e-13, 1e-15, 2.3355555555555556],
[1.3976506290323063, 22.762611855622463, 1, 1, 1, 3.0778804, 'DOP853', 1e-13, 1e-15, 2.667777777777778],
[1.5117311258028474, 21.695564131442726, 1, 1, 1, 2.98144533, 'DOP853', 1e-13, 1e-15, 3.0],
[1.6708004365129787, 19.982079503253374, 1, 1, 1, 2.86595516, 'DOP853', 1e-13, 1e-15, 3.5],
[1.9533518964731258, 17.603083685312168, 1, 1, 1, 2.70210934, 'DOP853', 1e-13, 1e-15, 4.5],
[2.080748598115769, 16.6238934134782, 1, 1, 1, 2.64150693, 'DOP853', 1e-13, 1e-15, 5],
[2.2007759544825785, 16.14721746352374, 1, 1, 1, 2.59041339, 'DOP853', 1e-13, 1e-15, 5.5],
[2.314476903963386, 15.27155301925415, 1, 1, 1, 2.54666877, 'DOP853', 1e-13, 1e-15, 6],
[2.422688656770652, 15.488616978521307, 1, 1, 1, 2.50873102, 'DOP853', 1e-13, 1e-15, 6.5],
[2.526092146099775, 14.916854445742127, 1, 1, 1, 2.47546786, 'DOP853', 1e-13, 1e-15, 7],
[2.6252477641284955, 14.67861149754133, 1, 1, 1, 2.44602799, 'DOP853', 1e-13, 1e-15, 7.5],
[2.72062164209113, 13.976100786416524, 1, 1, 1, 2.41975826, 'DOP853',1e-13, 1e-15, 8],
[2.812605281819515, 13.17880508250141, 1, 1, 1, 2.39614864, 'DOP853', 1e-13, 1e-15, 8.5],
[2.9015304296205127, 12.943109036960706, 1, 1, 1, 2.37479472, 'DOP853', 1e-13, 1e-15, 9.0],
[2.9876804910501154, 13.06427082561808, 1, 1, 1, 2.35537147, 'DOP853', 1e-13, 1e-15, 9.5],
[3.0712993941834634, 12.651007652264324, 1, 1, 1, 2.33761451, 'DOP853', 1e-13, 1e-15, 10],
[3.2317623458880727, 12.00421827176063, 1, 1, 1, 2.30626673, 'DOP853', 1e-13, 1e-15, 11],
[3.530031335443505, 10.982530382850403, 1, 1, 1, 2.25609566, 'DOP853', 1e-13, 1e-15, 13],
[3.8042492900820095, 10.56684783967323, 1, 1, 1, 2.21747106, 'DOP853', 1e-13, 1e-15, 15],
[4.059536168046426, 9.906109339227685, 1, 1, 1, 2.1866208, 'DOP853', 1e-13, 1e-15, 17],
[4.2994137602666225, 9.587909722378013, 1, 1, 1, 2.16127761, 'DOP853', 1e-13, 1e-15, 19],
[4.526422831434298, 9.15312554746657, 1, 1, 1, 2.1399922, 'DOP853', 1e-13, 1e-15, 21],
[4.742467147780788, 8.982897677403452, 1, 1, 1, 2.12179244, 'DOP853', 1e-13, 1e-15, 23],
[4.949017417902121, 8.524417669505688, 1, 1, 1, 2.10600043, 'DOP853', 1e-13, 1e-15, 25],
[5.1472385298026655, 8.630790236418383, 1, 1, 1, 2.09212811, 'DOP853', 1e-13, 1e-15, 27],
[5.430966723879008, 7.863413269578607, 1, 1, 1, 2.07415424, 'DOP853', 1e-13, 1e-15, 30],
[5.6121317537120845, 7.870460128205158, 1, 1, 1, 2.06368687, 'DOP853', 1e-13, 1e-15, 32],
[5.787616307241956, 7.643428902850742, 1, 1, 1, 2.05420675, 'DOP853', 1e-13, 1e-15, 34],
[5.957925646032471, 7.352091868934562, 1, 1, 1, 2.04556638, 'DOP853', 1e-13, 1e-15, 36],
[6.123493844226111, 7.202023558025553, 1, 1, 1, 2.03764737, 'DOP853', 1e-13, 1e-15, 38],
[6.284697180121865, 7.044019425346006, 1, 1, 1, 2.03035349, 'DOP853', 1e-13, 1e-15, 40],
[6.441864433099871, 6.810304837613603, 1, 1, 1, 2.02360561, 'DOP853', 1e-13, 1e-15, 42],
[6.595284921585597, 6.758981364242157, 1, 1, 1, 2.017338, 'DOP853', 1e-13, 1e-15, 44],
[6.745214862704277, 6.7448972906388, 1, 1, 1, 2.01149558, 'DOP853', 1e-13, 1e-15, 46],
[6.891882465130102, 6.6946255755681525, 1, 1, 1, 2.00603174, 'DOP853', 1e-13, 1e-15, 48],
[7.03549205201459, 6.367416938630397, 1, 1, 1, 2.0009068, 'DOP853', 1e-13, 1e-15, 50],
[7.38230037708338, 6.224909045017244, 1, 1, 1, 1.98936488, 'DOP853', 1e-13, 1e-15, 55],
[7.71352834525892, 6.048716886004579, 1, 1, 1, 1.97932076, 'DOP853', 1e-13, 1e-15, 60],
[8.031105011261308, 5.739326540161879, 1, 1, 1, 1.97047367, 'DOP853', 1e-13, 1e-15, 65],
[8.336591227271809, 5.45357960330077, 1, 1, 1, 1.96260173, 'DOP853', 1e-13, 1e-15, 70],
[9.460393448801062, 4.961368686689944, 1, 1, 1, 1.93802129, 'DOP853', 1e-13, 1e-15, 90],
[9.974925713407073, 4.720446136046833, 1, 1, 1, 1.92861496, 'DOP853', 1e-13, 1e-15, 100],
[10.46418764571049, 4.532033621558502, 1, 1, 1, 1.92052855, 'DOP853', 1e-13, 1e-15, 110],
# [12.226996124683483, 3.8337785770509027, 1, 1, 1, 1.89676857, 'DOP853', 1e-13, 1e-15, 150],
# [14.474100942127246, 3.6091560503052755, 1, 1, 1, 1.87491902, 'RK45', 1e-06, 1e-08, 210]
],
[  # Lambda=-1
 [5.39400050190153e-05, 3545.7495427879658, 1, -1, 1, 455.92904378, 'DOP853', 1e-13, 1e-15, 6.526413686780407e-05],
 [0.00013786993097575362, 2186.4999484117525, 1, -1, 1, 285.17793092, 'DOP853', 1e-13, 1e-15, 0.0001668100537200059],
 [0.0003836596049620056, 1366.4940629138366, 1, -1, 1, 170.95099416, 'DOP853', 1e-13, 1e-15, 0.00046415888336127773],
 [0.0004959584708306153, 1228.1025304765706, 1, -1, 1, 150.35547943, 'DOP853', 1e-13, 1e-15, 0.0006],
 [0.0006613108138235901, 1038.8185475836733, 1, -1, 1, 130.20721532, 'DOP853', 1e-13, 1e-15, 0.0008],
 [0.0008266795882452271, 928.1810814346907, 1, -1, 1, 116.45689394, 'DOP853', 1e-13, 1e-15, 0.001],
 [0.0010677750835643707, 850.5517367450402, 1, -1, 1, 102.467941, 'DOP853', 1e-13, 1e-15, 0.0012915496650148827],
 [0.001157466443578059, 815.1424455885999, 1, -1, 1, 98.41731168, 'DOP853', 1e-13, 1e-15, 0.0014],
 [0.001405599740246899, 725.4075404649964, 1, -1, 1, 89.3076757, 'DOP853', 1e-13, 1e-15, 0.0017],
 [0.001653770038496205, 716.5527404612045, 1, -1, 1, 82.33338642, 'DOP853', 1e-13, 1e-15, 0.002],
 [0.0019847213452965917, 614.9343992951649, 1, -1, 1, 75.15461541, 'DOP853', 1e-13, 1e-15, 0.0024],
 [0.002315738475386908, 569.5425986208305, 1, -1, 1, 69.57489481, 'DOP853', 1e-13, 1e-15, 0.0028],
 [0.002481271731797463, 550.9944069363796, 1, -1, 1, 67.21343535, 'DOP853', 1e-13, 1e-15, 0.003],
 [0.002972848306216136, 538.5535807242073, 1, -1, 1, 61.4037415, 'DOP853', 1e-13, 1e-15, 0.003593813663804626],
 [0.003309185049674923, 479.3643838497563, 1, -1, 1, 58.19858687, 'DOP853', 1e-13, 1e-15, 0.004],
 [0.00496624808772772, 398.48309858538346, 1, -1, 1, 47.5026842, 'DOP853', 1e-13, 1e-15, 0.006],
 [0.006624962214603514, 352.46697886980525, 1, -1, 1, 41.12444072, 'DOP853', 1e-13, 1e-15, 0.008],
 [0.00828533050004232, 323.68960214163627, 1, -1, 1, 36.77020931, 'DOP853', 1e-13, 1e-15, 0.01],
 [0.011611041864659555, 263.6833118954935, 1, -1, 1, 31.05517174, 'DOP853', 1e-13, 1e-15, 0.014],
 [0.016612092294900897, 229.0041044260045, 1, -1, 1, 25.95582506, 'DOP853', 1e-13, 1e-15, 0.02],
 [0.02498067303698938, 185.7056740395306, 1, -1, 1, 21.15631143, 'DOP853', 1e-13, 1e-15, 0.03],
 [0.03339146535701225, 167.8288894346937, 1, -1, 1, 18.29019391, 'DOP853', 1e-13, 1e-15, 0.04],
 [0.041844866944607526, 147.43200807988768, 1, -1, 1, 16.33081995, 'DOP853', 1e-13, 1e-15, 0.05],
 [0.05034128063054871, 133.76077269130533, 1, -1, 1, 14.88192087, 'DOP853', 1e-13, 1e-15, 0.06],
 [0.05888111447056481, 126.17537986264425, 1, -1, 1, 13.75384517, 'DOP853', 1e-13, 1e-15, 0.07],
 [0.0674647818307992, 116.58541531939848, 1, -1, 1, 12.84291413, 'DOP853', 1e-13, 1e-15, 0.08],
 [0.0760927014749509, 110.71268203045999, 1, -1, 1, 12.08703, 'DOP853', 1e-13, 1e-15, 0.09],
 [0.08476529765313111, 104.62378743861404, 1, -1, 1, 11.4464278, 'DOP853', 1e-13, 1e-15, 0.1],
 [0.1022462445895957, 95.34921090854557, 1, -1, 1, 10.41185211, 'DOP853', 1e-13, 1e-15, 0.12],
 [0.11991112985819076, 88.60023534376873, 1, -1, 1, 9.60484292, 'DOP853', 1e-13, 1e-15, 0.14],
 [0.13776355445002042, 83.78412657828002, 1, -1, 1, 8.95193209, 'DOP853', 1e-13, 1e-15, 0.16],
 [0.15580721629989647, 78.12527086652156, 1, -1, 1, 8.40910157, 'DOP853', 1e-13, 1e-15, 0.18],
 [0.1740459135862945, 77.29959235099462, 1, -1, 1, 7.94815454, 'DOP853', 1e-13, 1e-15, 0.2],
 [0.19248354816676527, 71.03425802243838, 1, -1, 1, 7.55007992, 'DOP853', 1e-13, 1e-15, 0.22],
 [0.21112412915538203, 68.97157686759402, 1, -1, 1, 7.20152976, 'DOP853', 1e-13, 1e-15, 0.24],
 [0.2299717766490677, 65.16805642327692, 1, -1, 1, 6.89281874, 'DOP853', 1e-13, 1e-15, 0.26],
 [0.24903072561006745, 64.5662320321775, 1, -1, 1, 6.61672492, 'DOP853', 1e-13, 1e-15, 0.28],
 [0.26830532991222744, 60.713610657159336, 1, -1, 1, 6.36773805, 'DOP853', 1e-13, 1e-15, 0.3],
 [0.2878000665592093, 58.74084161778839, 1, -1, 1, 6.14157057, 'DOP853', 1e-13, 1e-15, 0.32],
 [0.30972466979290114, 57.96779128800891, 1, -1, 1, 5.91293332, 'DOP853', 1e-13, 1e-15, 0.34222222222222226],
 [0.3274684871329696, 59.0694308164168, 1, -1, 1, 5.74478844, 'DOP853', 1e-13, 1e-15, 0.36],
 [0.3476517812615394, 54.72998353259115, 1, -1, 1, 5.56923024, 'DOP853', 1e-13, 1e-15, 0.38],
 [0.3680744379224563, 53.887883895339705, 1, -1, 1, 5.40632865, 'DOP853', 1e-13, 1e-15, 0.4],
 [0.38874161968654686, 51.7806303880658, 1, -1, 1, 5.25456482, 'DOP853', 1e-13, 1e-15, 0.42],
 [0.40965864168987287, 50.06618755902454, 1, -1, 1, 5.1126635, 'DOP853', 1e-13, 1e-15, 0.44],
 [0.43083097732511666, 49.968292391995995, 1, -1, 1, 4.97954498, 'DOP853', 1e-13, 1e-15, 0.46],
 [0.4522642641892386, 49.864109575282036, 1, -1, 1, 4.85428804, 'DOP853', 1e-13, 1e-15, 0.48],
 [0.4739643103008754, 47.083911466033285, 1, -1, 1, 4.73610123, 'DOP853', 1e-13, 1e-15, 0.5],
 [0.4959371006019657, 45.774531553247044, 1, -1, 1, 4.62430019, 'DOP853', 1e-13, 1e-15, 0.52],
 [0.518188803758831, 44.707570496172494, 1, -1, 1, 4.51828969, 'DOP853', 1e-13, 1e-15, 0.54],
 [0.5407257792790561, 45.638422295827446, 1, -1, 1, 4.4175492, 'DOP853', 1e-13, 1e-15, 0.56],
 [0.5635545849613267, 43.47309675553166, 1, -1, 1, 4.32162121, 'DOP853', 1e-13, 1e-15, 0.58],
 [0.5866819846967593, 43.354022328964966, 1, -1, 1, 4.23010175, 'DOP853', 1e-13, 1e-15, 0.6],
 [0.6101149566411767, 42.35670586596823, 1, -1, 1, 4.14263251, 'DOP853', 1e-13, 1e-15, 0.62],
 [0.6338607017792782, 43.573399173073035, 1, -1, 1, 4.05889446, 'DOP853', 1e-13, 1e-15, 0.64],
 [0.6755110789845782, 40.40853216977035, 1, -1, 1, 3.92261138, 'DOP853', 1e-13, 1e-15, 0.6744444444444445],
 [0.6823204840269396, 40.24244122463593, 1, -1, 1, 3.90150048, 'DOP853', 1e-13, 1e-15, 0.68],
 [0.6946428210995466, 41.30596664694041, 1, -1, 1, 3.86407297, 'DOP853', 1e-13, 1e-15, 0.69],
 [0.7070501202687316, 40.41009412717287, 1, -1, 1, 3.82735846, 'DOP853', 1e-13, 1e-15, 0.7],
 [0.7195434131100171, 39.208264125935585, 1, -1, 1, 3.79133163, 'DOP853', 1e-13, 1e-15, 0.71],
 [0.732123748217121, 39.178068527689675, 1, -1, 1, 3.75596839, 'DOP853', 1e-13, 1e-15, 0.72],
 [0.744792191554873, 39.545363635190796, 1, -1, 1, 3.7212458, 'DOP853', 1e-13, 1e-15, 0.73],
 [0.7575498268209304, 39.12176032450681, 1, -1, 1, 3.68714199, 'DOP853', 1e-13, 1e-15, 0.74],
 [0.7703977558166346, 38.79331736892957, 1, -1, 1, 3.6536361, 'DOP853', 1e-13, 1e-15, 0.75],
 [0.7963689950117148, 38.46732804116694, 1, -1, 1, 3.58833939, 'DOP853', 1e-13, 1e-15, 0.77],
 [0.8227151003164648, 37.98083246868234, 1, -1, 1, 3.52520693, 'DOP853', 1e-13, 1e-15, 0.79],
 [0.8494455779304337, 37.18525502691038, 1, -1, 1, 3.46410276, 'DOP853', 1e-13, 1e-15, 0.81],
 [0.8765702627162224, 36.70849557663652, 1, -1, 1, 3.4049023, 'DOP853', 1e-13, 1e-15, 0.83],
 [0.9040993325582869, 35.67341474935651, 1, -1, 1, 3.34749119, 'DOP853', 1e-13, 1e-15, 0.85],
 [0.9320433234861059, 35.49631279662652, 1, -1, 1, 3.29176416, 'DOP853', 1e-13, 1e-15, 0.87],
 [0.9604131456107117, 34.68522392549653, 1, -1, 1, 3.23762416, 'DOP853', 1e-13, 1e-15, 0.89],
 [0.9892200999272251, 34.29674821321327, 1, -1, 1, 3.18498151, 'DOP853', 1e-13, 1e-15, 0.91],
 [1.0184758960402485, 34.02112640967652, 1, -1, 1, 3.13375321, 'DOP853', 1e-13, 1e-15, 0.93],
 [1.04819267087343, 33.96451489860638, 1, -1, 1, 3.0838623, 'DOP853', 1e-13, 1e-15, 0.95],
 [1.0936598230922028, 33.39481721436713, 1, -1, 1, 3.01137848, 'DOP853', 1e-13, 1e-15, 0.98],
 [1.1245851294058735, 32.764536525580176, 1, -1, 1, 2.96452897, 'DOP853', 1e-13, 1e-15, 1.0],
 [1.2871132974260135, 31.1108313183659, 1, -1, 1, 2.74583392, 'DOP853', 1e-13, 1e-15, 1.1],
 [1.46428786147909, 29.57882572504385, 1, -1, 1, 2.54880413, 'DOP853', 1e-13, 1e-15, 1.2],
 [2.3761155844276036, 24.654537222149195, 1, -1, 1, 1.90058128, 'DOP853', 1e-13, 1e-15, 1.6],
 [2.433163024739402, 24.6193050822199, 1, -1, 1, 1.8721518, 'DOP853', 1e-13, 1e-15, 1.62],
 [2.491625930234563, 24.61333484313852, 1, -1, 1, 1.8439883, 'DOP853', 1e-13, 1e-15, 1.64],
 [2.551563284740297, 24.03660224053762, 1, -1, 1, 1.81607831, 'DOP853', 1e-13, 1e-15, 1.66],
 [2.613037637388466, 24.103878323567862, 1, -1, 1, 1.78840968, 'DOP853', 1e-13, 1e-15, 1.68],
 [2.676115408901437, 24.279506685140323, 1, -1, 1, 1.76097056, 'DOP853', 1e-13, 1e-15, 1.7],
 [3.0181982482050116, 24.30800510016198, 1, -1, 1, 1.62681837, 'DOP853', 1e-13, 1e-15, 1.8],
 [3.4133018398266564, 22.42505472947886, 1, -1, 1, 1.49672604, 'DOP853', 1e-13, 1e-15, 1.9],
 [3.8773057509493483, 22.0266315009791, 1, -1, 1, 1.36928015, 'DOP853', 1e-13, 1e-15, 2.0],
 [4.435127186635542, 19.889301212887002, 1, -1, 1, 1.24279257, 'DOP853', 1e-13, 1e-15, 2.1],
 [5.130999178317605, 24.657341958527766, 1, -1, 1, 1.11468526, 'DOP853', 1e-13, 1e-15, 2.2],
 [6.062684389079408, 18.029116201034597, 1, -1, 1, 0.9794575, 'DOP853', 1e-13, 1e-15, 2.3],
 [7.601340944008028, 24.81946831861469, 1, -1, 1, 0.81542827, 'DOP853', 1e-13, 1e-15, 2.4],
 [7.8, 25, 1, -1, 1, 0.81542827, 'DOP853', 1e-13, 1e-15, 2.40796471368545],
 [8., 15, 1, -1, 1, 0.81542827, 'DOP853', 1e-13, 1e-15, 2.41495423],
 [8.25, 20.14378182397762, 1, -1, 1, 0.76142823, 'DOP853', 1e-13, 1e-15, 2.422281378535987],
[8.5, 14.786207323943152, 1, -1, 1, 0.74244316, 'DOP853', 1e-13, 1e-15, 2.4280881527172387],
[8.75, 14.465599462707763, 1, -1, 1, 0.72436365, 'DOP853', 1e-13, 1e-15, 2.4324196679554335],
[9.0, 18.261637222373416, 1, -1, 1, 0.70712669, 'DOP853', 1e-13, 1e-15, 2.4353170623193146],
[9.25, 13.932113523356135, 1, -1, 1, 0.69067502, 'DOP853', 1e-13, 1e-15, 2.436818010897661],
[9.5, 13.653222342366544, 1, -1, 1, 0.67495648, 'DOP853', 1e-13, 1e-15, 2.436957147740281],
[10.5, 17.94187634134773, 1, -1, 1, 0.61851929, 'DOP853', 1e-13, 1e-15, 2.4245007165942223],
[11, 16.21768073173295, 1, -1, 1, 0.59363478, 'DOP853', 1e-13, 1e-15, 2.4108316093171624],
[12, 12.959217339736323, 1, -1, 1, 0.54932561, 'DOP853', 1e-13, 1e-15, 2.3694886561797004],
[13, 18.987821888767478, 1, -1, 1, 0.5110655, 'DOP853', 1e-13, 1e-15, 2.3104277698711284]
]]

# %%
Umax = 2.8
Umin = 2.3
f0 = 13
nodos = 1
alf = 1
rmin = 0
rmax = 1e03
met='DOP853'
Rtol= 1e-13
Atol = 1e-15

# en, Mas, rD, sD, dsD, uD, duD, cer0, LamV  = ru.profiles2(nodos, Lam, f0, umin=Umin, umax=Umax, met='DOP853')

datos = []
for i in [-1]:
    Lamb = i 
    U0, rTemp, posNodos = ru.Freq_solveG2(f0, Umax, Umin, Lamb, alf, rmax, rmin, nodos,met=met,
                                  Rtol=Rtol, Atol=Atol)

    datos.append([f0, rTemp, alf, i, nodos, posNodos, met, Rtol, Atol, U0])

# %%
datos

# %%
soluciones_Fondo = [
[8.25, 20.14378182397762, 1, -1, 1, 0.76142823, 'DOP853', 1e-13, 1e-15, 2.422281378535987],
[8.5, 14.786207323943152, 1, -1, 1, 0.74244316, 'DOP853', 1e-13, 1e-15, 2.4280881527172387],
[8.75, 14.465599462707763, 1, -1, 1, 0.72436365, 'DOP853', 1e-13, 1e-15, 2.4324196679554335],
[9.0, 18.261637222373416, 1, -1, 1, 0.70712669, 'DOP853', 1e-13, 1e-15, 2.4353170623193146],
[9.25, 13.932113523356135, 1, -1, 1, 0.69067502, 'DOP853', 1e-13, 1e-15, 2.436818010897661],
[9.5, 13.653222342366544, 1, -1, 1, 0.67495648, 'DOP853', 1e-13, 1e-15, 2.436957147740281],
[10.5, 17.94187634134773, 1, -1, 1, 0.61851929, 'DOP853', 1e-13, 1e-15, 2.4245007165942223],
[11, 16.21768073173295, 1, -1, 1, 0.59363478, 'DOP853', 1e-13, 1e-15, 2.4108316093171624],
[12, 12.959217339736323, 1, -1, 1, 0.54932561, 'DOP853', 1e-13, 1e-15, 2.3694886561797004],
[13, 18.987821888767478, 1, -1, 1, 0.5110655, 'DOP853', 1e-13, 1e-15, 2.3104277698711284]
]

# %%
soluciones_Fondo = DataFondo[2][-30:]

# %%
soluciones_Fondo = [ [7.8, 23, 1, -1, 1, 0.81542827, 'DOP853', 1e-13, 1e-15, 2.40796471368545]]

# %%
##########################
# EXTENDIENDO SOLUCIONES #
##########################
Ncasos = range(len(soluciones_Fondo))

datosProfiles = []
Edata = []
for i in Ncasos:
    datBG = soluciones_Fondo[i]
    s0 = datBG[0]
    r0M = datBG[1]
    Ext = (s0*r0M)+7000
    Np = int(Ext/2)
    rtake = -160
    # Resolviendo
    en, Mas, rD, sD, dsD, uD, duD, cer0, LamV = ru.profilesFromSolut(datBG) 
    # Extendiendo
    rDnew, sDnew, dsDnew, uDnew, duDnew, datosEquiv = ru.extend(rD[:rtake], sD[:rtake], dsD[:rtake], uD[:rtake], duD[:rtake],
                                                                Ext, Np, inf=False)
    print(Ext, Np, r0M, rDnew[-1])

    # interpolación de los datos
    fsN = interp1d(rDnew, sDnew, kind='quadratic') # quadratic
    fdsN = interp1d(rDnew, dsDnew, kind='linear')
    fuN = interp1d(rDnew, uDnew, kind='quadratic')
    fduN = interp1d(rDnew, duDnew, kind='quadratic')

    # Equivalencia
    masatest, Entest, sD0test = datosEquiv  # M -> K
    Edata.append([rDnew[-1], Entest, (Entest-uDnew)[-1], fsN(rDnew[-1])])

    #plt.plot(rDnew, np.abs(Entest-uDnew), label=r'%d'%i)  # u = E - Uf
    plt.plot(rD, sD, label=r'%d'%i)  # u = E - Uf
    # salvando
    datosProfiles.append([fsN, fdsN, fuN, fduN])
    
plt.legend()
#plt.xscale('log')
#plt.yscale('log')

plt.xlim(0, 30)

# %%
 #rDnew, sDnew, dsDnew, uDnew, duDnew

 #np.savetxt('rSU.dat', np.array([ rDnew, sDnew, uDnew]))

# %%
#########################################
# Calculando los autovalores (Espectro) #
#########################################

def NpuntosCho(s0):
  if s0>=3.5:
    Nptos = int(rMax/2)
  elif s0>=2.5:
    Nptos = int(rMax/4)
  elif s0>=1.5:
    Nptos = int(rMax/5)
  elif s0>=0.5:
    Nptos = int(rMax/6)
  elif s0>=0.05:
    Nptos = int(rMax/7)
  else:
    Nptos = int(rMax/8)
  return Nptos

dist = [0.7, 0.8, 0.9, 1]
ptosVal = [100, 250, 500, 750, 1000]

# Ncasos = range(len(datosProfiles))  # numero de soluciones que se estudiarán

# cada fila es un valor de Nptos y columna una solución sigma0
Lval = 1
Auto_Real, Auto_Valores, Auto_Funciones = [], [], []
dataPtos = []
for k in Ncasos: #Ncasos:
    fsNtmp, fuNtmp = datosProfiles[k][0], datosProfiles[k][2]
    rfin, alpha, Lamb, nodos = soluciones_Fondo[k][1], soluciones_Fondo[k][2], soluciones_Fondo[k][3], soluciones_Fondo[k][4]
    
    s0 = fsNtmp(0)
    rMax = rfin+200*(nodos+1) #dist[2]*rDnew[-1]  #rfin+200*(nodos+1)
    Nptos = NpuntosCho(s0)+1000#1500 #NpuntosCho(s0)+ptosVal[3] # NpuntosCho(s0)+1000
    dataPtos.append([s0, rMax, Nptos])
    print(Nptos, fsNtmp(rMax), Edata[k][1]-fuNtmp(rMax))
    
    L = Lval
    util = [Nptos, rMax, Lamb, alpha, L]    
    datFunc = [fsNtmp, fuNtmp]

    lambd, _, Vecto_Full, _ = ru.espectroL(datFunc, util, inf=False)

    #### Separando los Autovalores ######
    jj = np.real(lambd)!=0  # reales
    autoval_Real = lambd[jj]
    print('Autovalores con part. Real para rho_0=%7.6f, Npt.=%d -> '%(fsNtmp(0), Nptos), autoval_Real)
    print('')
    
    if len(autoval_Real)!=0:
        #temp = len(autoval_Real)
        #name = 'data_real%d.dat'%(k)
        #data = np.array([[k]*temp, autoval_Real.real, autoval_Real.imag]).T
        #np.savetxt(name, data)
        Auto_Real.append(k)
    ###############

    ###### Organizando de menor a mayor los autovalores #####
    indF = ru.menor(lambd).astype(int)
    autova_Organ = lambd[indF]

    ###### Salvando  #####
    Auto_Valores.append(autova_Organ)
    Auto_Funciones.append(Vecto_Full[:, indF])

# %%
Autovalores2P = []
for i in Auto_Valores:
    jj = np.real(i)!=0  # reales
    kk = np.real(i)>8e-03
    jj=kk*jj
    autoval_Real = i[jj]
    Autovalores2P.append(autoval_Real)

# %%
s0data = [i[0] for i in soluciones_Fondo]

# %%
#Auto_Valores
np.save('AutovN1ML1_2.npy', np.array([s0data, Autovalores2P], dtype=object))

# %%
Lamb = 1  # 0, 1

k = 4

autoV = 0
print(Auto_Valores[k])
print('')

nodos = 0
rfin = rMax
# s0 = radSigmMasaN_P[k][1][0]

#rMax = rfin*(nodos+1) 
#Nptos = int(3*rMax/4) + 500

s0, rMax, Nptos = dataPtos[k]
#s0 = fsNtmp(0)
#rMax = Edata[k][0] #rfin+200*s0**2 # rfin*(nodos+1) #rfin*(nodos+1) # rfin+200*(nodos+1)
#Nptos = NpuntosCho(s0)+500

utilez = [k, Nptos, rMax]
r_dis, datA, datB = ru.VectoresAB(autoV, Auto_Funciones, Auto_Valores, utilez)

# %%
# tests

# %%
#k = 15
col = ['#1a1919', '#f0784d', '#2681ab', '#ab262f', '#bc92e0', '#486318', '#ed5b0c', 
      '#f0a092', '#484f07', '#694d0c']
Ls = ['-', '--', ':', '.-']

rP = rDnew 
sP = sDnew

cte = sP.max()/np.abs(datB[0]).max()

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 5.),
                       sharex=False, sharey=True,
                       gridspec_kw=dict(hspace=0.0, wspace=.15))

left, bottom, width, height = [0.295, 0.56, 0.18, 0.28]
ax1 = fig.add_axes([left, bottom, width, height])
left, bottom, width, height = [0.71, 0.56, 0.18, 0.28]
ax2 = fig.add_axes([left, bottom, width, height])

ax[0].plot(r_dis[1:Nptos], np.real(datB[0])*cte, ls=Ls[0], lw=1, c=col[2], marker='o', label=r'$\sigma_0 = %7.6f$'%sP[0])  # label=r'$L = %d$'%(Lval[i])
ax1.plot(r_dis[1:Nptos], np.imag(datB[0])*cte,  ls=Ls[1], lw=1, c=col[2])

ax[1].plot(r_dis[1:Nptos], np.real(datA[0])*cte, ls=Ls[0], lw=1, c=col[2])
ax2.plot(r_dis[1:Nptos], np.imag(datA[0])*cte, ls=Ls[2], lw=1, c=col[2])

## fondo ##
#ax[0].plot(rP[::8], sP[::8], ls='', marker='o', markersize=5, mfc='white',
#           color=col[0])

ax[0].plot(rP, sP, ls='--', color=col[0])

ax[0].set_xlabel(r'$\bar{r}$')
ax[1].set_xlabel(r'$\bar{r}$')
ax[0].set_ylabel(r'Re $\bar{B}$')
ax[1].set_ylabel(r'Re $\bar{A}$')
ax1.set_ylabel(r'Im $\bar{B}$')#, labelpad=-5)
ax2.set_ylabel(r'Im $\bar{A}$')#, labelpad=-5)

xmin = 0
xmax = 30
ax[0].set_xlim(xmin, xmax)
ax[1].set_xlim(xmin, xmax)
#ax1.set_xlim(xmin, xmax)
#ax2.set_xlim(xmin, xmax)

#ax1.set_ylim(-0.001, 0.007)

ax1.set_xticks([])
ax2.set_xticks([])

temp = Auto_Valores[k][autoV]
#ax[0].text(x=10, y=0.2, s=r'$\lambda = (%7.6f, %7.6f)$'%(np.real(temp), np.imag(temp)))
ax[0].legend(loc='center right', frameon=False, title=r'Interaction %s'%Lamb)

# %%
Nptos = 668

D_chev, x_chev = ru.cheb(Nptos)
r_dis = np.array([(-x_chev[i]+1)*rMax/2. for i in range(Nptos+1)])

s0 = fsN(r_dis)
D_chev1 = np.copy(D_chev)/(rMax/2)  # [1:Nptos, 1:Nptos]

ds = np.gradient(s0, r_dis)
dsC = np.dot(D_chev1, s0)

plt.plot(r_dis, ds, ':')
plt.plot(rD, dsD, '-')
plt.plot(r_dis, dsC, '--')

plt.xlim(0, 10)
plt.ylim(0, -0.5)

# %%
D_chev, x_chev = ru.cheb(Nptos)
r_dis = np.array([(-x_chev[i]+1)*rMax/2. for i in range(Nptos+1)])
r_dis2 = np.copy(r_dis[1:Nptos])

D2_chev = np.dot(D_chev, D_chev)/((rMax/2)**2)  # Calculando D^2. Rescalando D_[0, L] = D[-1, 1]/(L/2)
D2i_chev = np.copy(D2_chev[1:Nptos, 1:Nptos])

Sigma0 = np.diag(fsN(r_dis2)) 
U0 = np.diag(fuN(r_dis2))  # potencial u0 = E-\triangle^{-1}(|sigma_{1}^{0}|^{2})

HopME = D2i_chev-Lamb*np.dot(Sigma0, Sigma0)+U0

MD = np.dot(HopME, datB[0]*r_dis2)*cte
MI = -1j*Auto_Valores[k][autoV]*datA[0]*r_dis2*cte

plt.plot(r_dis2, MD)
plt.plot(r_dis2, MD-MI, '--')
plt.xlim(0, 20)
